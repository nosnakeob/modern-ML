# %%
from torchvision.datasets import MNIST, FashionMNIST, CIFAR10
from utils.cv_utils import *


def show_data(DATASET):
    tr_set = DATASET('../data', train=True)

    print(len(tr_set))

    img, label = tr_set[0]
    print(img, label)
    show_cv_img(img)

# %%
show_data(MNIST)
show_data(FashionMNIST)
show_data(CIFAR10)
# Out:
# 60000
# <PIL.Image.Image image mode=L size=28x28 at 0x14D3C5879A0> 5
# 60000
# <PIL.Image.Image image mode=L size=28x28 at 0x14D3C595C70> 9
# 50000
# <PIL.Image.Image image mode=RGB size=32x32 at 0x14D4EAAB190> 6
